# %% [markdown]
# ### importing necessary libaries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### loading the data into the pandas dataframe and displaying the first five rows

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#              city    beat
# 0  Bengaluru City  BEAT 4
# 1  Bengaluru City  BEAT 2
# 2  Bengaluru City  BEAT 2
# 3  Bengaluru City  BEAT 2
# 4  Bengaluru City  BEAT 5

# %% [markdown]
# ### checking the number of rows and colomns

# %%
df.shape
# Out:
# (495787, 2)

# %% [markdown]
# ### displaying the names of coloumns

# %%
df.columns
# Out:
# Index(['city', 'beat'], dtype='object')

# %% [markdown]
# ### checking for any null values

# %%
df.isnull()
# Out:
#          city   beat
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 495782  False  False
# 495783  False  False
# 495784  False  False
# 495785  False  False
# 495786  False  False
#
# [495787 rows x 2 columns]

# %% [markdown]
# ### using another method i.e for loop for checking null values

# %%
features= ['city', 'beat']

# %%
for feature in features:
    null_check = pd.isnull(df[feature])
    print(df[null_check])
# Out:
# Empty DataFrame
# Columns: [city, beat]
# Index: []
#                   city beat
# 470958  Bengaluru Dist  NaN

# %% [markdown]
# ### droping the rows with null values

# %%
df = df.dropna()
df.shape
# Out:
# (495786, 2)

# %%
df['beat'].unique()
# Out:
# array(['BEAT 4', 'BEAT 2', 'BEAT 5', ..., 'BEAT   5', 'OTHER LIMITS',
#        'OTHER VILLAGE LIMITS'], dtype=object)

# %% [markdown]
# ### Grouping the crimes beat wise

# %%
df_crime = df.groupby('beat').size().reset_index(name = 'Numbers')
df_crime
# Out:
#                                 beat  Numbers
# 0                                  0        3
# 1                             0 BEAT       18
# 2               01 KASTURI BAI NAGAR      148
# 3                         01 ST BEAT      304
# 4                         02 ND BEAT      155
# ...                              ...      ...
# 1245                          thndlu        6
# 1246        vidyaranyapura main road       12
# 1247        w o c roard service road        9
# 1248  yelahanka by pass near railway      140
# 1249                               z       89
#
# [1250 rows x 2 columns]

# %% [markdown]
# ### Plotting the graph for analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(210,8))
plt.xlabel('Beat')
plt.title('Bangalore Beat Wise Crime Distribution')
plt.ylabel('Number of crimes')

x = df_crime['beat']
y = df_crime['Numbers']

# Plotting with adjusted x-axis labels
plt.bar(x, y)
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees for better readability

plt.grid(which='both', linestyle=':')
plt.tight_layout()

# Save the plot with adjusted x-axis labels
plt.savefig('new2.jpg', dpi=300)

# %% [markdown]
# ### The plot is exported in .jpg format for good visual represetaion
